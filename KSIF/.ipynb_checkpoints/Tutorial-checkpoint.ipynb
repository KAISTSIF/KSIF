# %% [markdown]
# # KSIF Libarary Tutorial
# This file shows how to use KSIF package using a simple example.
# You have to notice that the package is based on pre-existing package 'bt' and 'ffn'.
# See docs for more information.
#
# @KAIST Student Investment Fund
#
# *Seung Hyeon Yu*
# (rambor12@business.kaist.ac.kr)

# %%
import KSIF as kf

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Get data
# There are two ways to get the data.
# 1. **web** : This method is fundamentally using pandas_Datareader.
# 2. **pandas read_csv** : This method can read csv file formally.

# %% [markdown]
# If you don't explicitly write down the .csv file, 'get' function will get data from the web automatically.
# For example, you can download KOSPI, KOSDAQ, KOSPI200, KOSPI small Index using 'get' function.

# %%
data = kf.get('KOSPI, kosdaq, kospi200, kospismall',start='2010-01-01')

# %%
data
# Out:
#                   kospi      kosdaq  kospi200  kospismall
# Date
# 2013-03-04  2013.150024  537.380005    266.14     1382.60
# 2013-03-05  2016.609985  543.960022    266.54     1392.15
# 2013-03-06  2020.739990  544.359985    267.25     1396.39
# 2013-03-07  2004.400024  541.299988    264.78     1389.97
# 2013-03-08  2006.010010  543.099976    264.57     1393.71
# 2013-03-15  1986.500000  554.809998    260.84     1419.13
# 2013-03-22  1948.709961  551.250000    255.33     1405.84
# 2013-04-05  1927.229980  547.510010    252.77     1409.46
# 2013-04-08  1918.689941  528.780029    252.39     1384.52
# 2013-04-09  1920.739990  528.150024    252.53     1374.17
# 2013-04-10  1935.579956  534.840027    254.34     1393.90
# 2013-04-11  1949.800049  544.299988    256.18     1412.80
# 2013-04-12  1924.229980  547.190002    252.00     1424.98
# 2013-04-15  1920.449951  553.989990    251.51     1440.15
# 2013-04-16  1922.209961  558.950012    251.78     1443.28
# 2013-04-17  1923.839966  558.539978    251.51     1452.67
# 2013-04-18  1900.060059  551.099976    247.85     1454.30
# 2013-04-19  1906.750000  541.460022    248.77     1445.38
# 2013-04-25  1951.599976  559.400024    254.49     1494.79
# 2013-04-26  1944.560059  565.349976    253.04     1504.64
# 2013-04-30  1963.949951  563.869995    255.72     1509.87
# 2013-05-03  1965.709961  565.330017    256.02     1519.08
# 2013-05-10  1944.750000  569.700012    252.72     1552.26
# 2013-05-16  1986.810059  566.059998    258.99     1542.35
# 2013-05-24  1973.449951  574.059998    257.32     1546.11
# 2013-05-31  2001.050049  577.869995    261.47     1560.38
# 2013-06-05  1959.189941  549.090027    256.51     1525.31
# 2013-06-07  1923.849976  535.750000    251.20     1504.03
# 2013-06-14  1889.239990  536.039978    245.36     1487.16
# 2013-06-21  1822.829956  520.890015    236.57     1454.48
# ...                 ...         ...       ...         ...
# 2016-11-18  1974.579956  620.260010    250.21     2039.67
# 2016-11-21  1966.050049  609.330017    249.51     2011.87
# 2016-11-22  1983.469971  610.739990    252.37     2011.73
# 2016-11-23  1987.949951  600.289978    253.66     1992.73
# 2016-11-24  1971.260010  592.650024    252.03     1967.76
# 2016-11-25  1974.459961  597.820007    252.26     1978.07
# 2016-11-28  1978.130005  593.049988    252.96     1966.39
# 2016-11-29  1978.390015  596.070007    252.91     1972.54
# 2016-11-30  1983.479980  596.109985    254.26     1970.09
# 2016-12-01  1983.750000  593.849976    254.48     1964.57
# 2016-12-02  1970.609985  586.729980    252.88     1954.92
# 2016-12-05  1963.359985  575.119995    252.14     1926.61
# 2016-12-06  1989.859985  581.349976    255.63     1947.68
# 2016-12-07  1991.890015  578.520020    256.34     1937.62
# 2016-12-08  2031.069946  584.619995    262.00     1956.66
# 2016-12-09  2024.689941  594.349976    260.91     1971.44
# 2016-12-12  2027.239990  603.080017    260.72     2001.93
# 2016-12-13  2035.979980  611.090027    261.63     2017.73
# 2016-12-14  2036.869995  612.469971    262.00     2014.78
# 2016-12-15  2036.650024  620.609985    261.45     2032.14
# 2016-12-16  2042.239990  622.080017    262.56     2032.84
# 2016-12-19  2038.390015  622.770020    261.93     2038.91
# 2016-12-20  2041.939941  617.989990    262.59     2044.04
# 2016-12-21  2037.959961  618.630005    262.10     2046.04
# 2016-12-22  2035.729980  615.929993    261.97     2039.63
# 2016-12-23  2035.900024  619.750000    261.61     2045.15
# 2016-12-27  2042.170044  618.380005    262.49     2043.39
# 2016-12-28  2024.489990  627.270020    259.70     2047.62
# 2016-12-29  2026.459961  631.440002    260.01     2054.29
# 2017-01-03  2043.969971  636.570007    262.97     2068.18
#
# [877 rows x 4 columns]

# %% [markdown]
# # 2. Make Strategy
# The 'Strategy' need 2 arguments: strategy name and 'algos'.
# 1. **strategy name** : (e.g) 투자전략1호, SPP 가치투자전략 버전 1.2, EPT-Momentum, Passive01 etc...
# 2. **algos** : The building blocks of strategy. You have to make your own 'algo'.

# %% [markdown]
# Even though you have to make your own 'algo', KSIF package provide some basic 'algos'.
# 1. **Run(Daily, Monthly, Quarterly)** : this algo makes other algos run only once in a (Day, Month, Quarter).
# 2. **Select(All, Randomly, Where)** : this algo select specific Securities based on 'signal'.
# 3. **WeighEqually** : this algo set the weight of securities equally.
# 4. **Rebalanced** : Rebalance based on the weight of selected securities.
# 5. **LossCut** : If there is a security have a return below certain level, cut off.

# %%
s = kf.Strategy('투자전략1호', [kf.algos.RunDaily(), kf.algos.SelectRandomly(), kf.algos.WeighEqually(), kf.algos.Rebalance()])

# %% [markdown]
# ## 3. Make Backtest Instance
# The 'Backtest' need 2 arguments: strategy and price data.

# %%
test = kf.Backtest(s, data)

# %% [markdown]
# ## 4. Run
# You have to save the result object.

# %%
res = kf.run(test)
# Out:
# 투자전략1호
# 0%                          100%
# [##############################] | ETA: 00:00:02 | ETA: 00:00:02 | ETA: 00:00:01 | ETA: 00:00:01 | ETA: 00:00:01 | ETA: 00:00:01 | ETA: 00:00:01 | ETA: 00:00:01 | ETA: 00:00:01 | ETA: 00:00:01 | ETA: 00:00:01 | ETA: 00:00:01 | ETA: 00:00:01 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00
# Total time elapsed: 00:00:01

# %% [markdown]
# After you run the backtest, you can see the summary statistics.

# %%
res.display()
# Out:
# Stat                 투자전략1호
# -------------------  -------------
# Start                2013-03-04
# End                  2017-01-03
# Risk-free rate       0.00%
#
# Total Return         14.12%
# Daily Sharpe         0.37
# CAGR                 3.50%
# Max Drawdown         -16.96%
#
# MTD                  0.87%
# 3m                   -2.25%
# 6m                   -0.57%
# YTD                  0.87%
# 1Y                   1.77%
# 3Y (ann.)            6.06%
# 5Y (ann.)            3.50%
# 10Y (ann.)           3.50%
# Since Incep. (ann.)  3.50%
#
# Daily Sharpe         0.37
# Daily Mean (ann.)    4.57%
# Daily Vol (ann.)     12.39%
# Daily Skew           -0.62
# Daily Kurt           2.92
# Best Day             3.05%
# Worst Day            -3.89%
#
# Monthly Sharpe       0.46
# Monthly Mean (ann.)  4.38%
# Monthly Vol (ann.)   9.55%
# Monthly Skew         -0.51
# Monthly Kurt         0.52
# Best Month           4.91%
# Worst Month          -7.95%
#
# Yearly Sharpe        0.87
# Yearly Mean          4.11%
# Yearly Vol           4.75%
# Yearly Skew          1.56
# Yearly Kurt          2.20
# Best Year            10.95%
# Worst Year           0.87%
#
# Avg. Drawdown        -2.47%
# Avg. Drawdown Days   47.41
# Avg. Up Month        2.50%
# Avg. Down Month      -1.97%
# Win Year %           100.00%
# Win 12m %            77.78%

# %% [markdown]
# Also you can see the portfolios with the positions.

# %%
test.portfolios
# Out:
# Date
# 2013-03-04  kosdaq           0.0
#             kospi            0.0
#             kospi200         0.0
#             kospismall       0.0
# 2013-03-05  kosdaq         459.0
#             kospi          123.0
#             kospi200       937.0
#             kospismall     179.0
# 2013-03-06  kosdaq         457.0
#             kospi          123.0
#             kospi200       932.0
#             kospismall     178.0
# 2013-03-07  kosdaq         457.0
#             kospi          123.0
#             kospi200       934.0
#             kospismall     178.0
# 2013-03-08  kosdaq         456.0
#             kospi          123.0
#             kospi200       937.0
#             kospismall     177.0
# 2013-03-15  kosdaq         448.0
#             kospi          125.0
#             kospi200       954.0
#             kospismall     175.0
# 2013-03-22  kosdaq         445.0
#             kospi          125.0
#             kospi200       961.0
#             kospismall     174.0
# 2013-04-05  kosdaq         445.0
#             kospi          126.0
#                            ...
# 2016-12-20  kospi200      1074.0
#             kospismall     138.0
# 2016-12-21  kosdaq         455.0
#             kospi          138.0
#             kospi200      1076.0
#             kospismall     137.0
# 2016-12-22  kosdaq         456.0
#             kospi          138.0
#             kospi200      1074.0
#             kospismall     137.0
# 2016-12-23  kosdaq         454.0
#             kospi          138.0
#             kospi200      1077.0
#             kospismall     137.0
# 2016-12-27  kosdaq         456.0
#             kospi          138.0
#             kospi200      1075.0
#             kospismall     138.0
# 2016-12-28  kosdaq         449.0
#             kospi          139.0
#             kospi200      1085.0
#             kospismall     137.0
# 2016-12-29  kosdaq         447.0
#             kospi          139.0
#             kospi200      1087.0
#             kospismall     137.0
# 2017-01-03  kosdaq         448.0
#             kospi          139.0
#             kospi200      1084.0
#             kospismall     137.0
# dtype: float64

# %% [markdown]
# Here is a plot the graph.

# %%
res.plot()
plt.show()

# %% [markdown]
# Also you can see the histogram of return.

# %%
res.plot_histogram()
plt.show()

# %% [markdown]
# The whole backtest result can be saved as 'log file'. You can reuse this log file to backtest again.

# %%
res.save()
# Out:
# True

# %% [markdown]
# Tutorial End.
